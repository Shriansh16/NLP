# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriansh16/NLP/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import nltk
import re
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df=pd.read_csv('/content/labeled_data.csv')

# %%
df.shape
# Out:
# (24783, 7)

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.drop(columns=['Unnamed: 0','count','hate_speech','offensive_language','neither'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.isnull().sum()
# Out:
# class    0
# tweet    0
# dtype: int64

# %%
df.duplicated().sum(0)
# Out:
# 0

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='class'>

# %%
df['class']=df['class'].apply(lambda x: 0 if x == 1 else x)

# %%
df['class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='class'>

# %%
df['class']=df['class'].apply(lambda x: 1 if x == 2 else x)

# %%
df['class'].value_counts()
# Out:
# class
# 0    20620
# 1     4163
# Name: count, dtype: int64

# %%
df['class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='class'>

# %% [markdown]
# ###0-> HATE SPEECH
# ###1-> NORMAL

# %%
# !unzip '/content/archive (29).zip'
# Out:
# Archive:  /content/archive (29).zip
#   inflating: Twitter_Data.csv

# %%
df1=pd.read_csv('/content/Twitter_Data.csv')

# %%
df1.head()
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %% [markdown]
# negative(-1), neutral(0), and positive(+1)

# %%
k=df1[df1['category'] == 0].head(16000)

# %%
k.reset_index(drop=True,inplace=True)

# %%
k.head()
# Out:
#                                           clean_text  category
# 0  talk all the nonsense and continue all the dra...       0.0
# 1           kiya tho refresh maarkefir comment karo        0.0
# 2  surat women perform yagna seeks divine grace f...       0.0
# 3  this comes from cabinet which has scholars lik...       0.0
# 4  one vote can make all the difference anil kapo...       0.0

# %%
df.head()
# Out:
#    class                                              tweet
# 0      1  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      0  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      0  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      0  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      0  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
k.rename(columns={'clean_text':'tweet'},inplace=True)

# %%
df.rename(columns={'class':'category'},inplace=True)

# %%
k['category']=1

# %%
k.head()
# Out:
#                                                tweet  category
# 0  talk all the nonsense and continue all the dra...         1
# 1           kiya tho refresh maarkefir comment karo          1
# 2  surat women perform yagna seeks divine grace f...         1
# 3  this comes from cabinet which has scholars lik...         1
# 4  one vote can make all the difference anil kapo...         1

# %%
final_df=pd.concat([df,k])

# %%
final_df.head()
# Out:
#    category                                              tweet
# 0         1  !!! RT @mayasolovely: As a woman you shouldn't...
# 1         0  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2         0  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3         0  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4         0  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
final_df.reset_index(drop=True,inplace=True)

# %%
final_df['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# ###0-> HATE SPEECH
# ###1-> NORMAL

# %%
final_df.to_csv('twitter_final_data.csv')

# %%
import string

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer=PorterStemmer()

# %%
def data_cleaning(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    words=nltk.word_tokenize(text)
    words=[stemmer.stem(word) for word in words if word not in stopwords.words('english')]
    return ' '.join(words)

# %%
final_df['cleaned_tweet']=final_df['tweet'].apply(data_cleaning)

# %%
final_df
# Out:
#        category                                              tweet  \
# 0             1  !!! RT @mayasolovely: As a woman you shouldn't...
# 1             0  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2             0  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3             0  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4             0  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...         ...                                                ...
# 40778         1  modi promo discount for annual membership ends...
# 40779         1  current announcement modi hence place vote bjp...
# 40780         1                 congratulations drdoisro and modi
# 40781         1             modi will kill thanos know yeaaaa modi
# 40782         1           modi’ announcement expectations reality
#
#                                            cleaned_tweet
# 0      rt mayasolov woman shouldnt complain clean hou...
# ...

# %%
X=final_df['cleaned_tweet']
y=final_df['category']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, SpatialDropout1D
from tensorflow.keras.optimizers import RMSprop

# %%
max_words = 50000
max_len = 300
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)

# %% [markdown]
# max_words = 50000: This sets the maximum number of words to consider in the tokenizer's vocabulary. Only the most frequent max_words words will be kept, and the rest will be discarded.
#
#
#
# max_len = 300: This sets the maximum length of each sequence. Sequences longer than this will be truncated, and sequences shorter than this will be padded.
#
#
#
# tokenizer = Tokenizer(num_words=max_words): This initializes a tokenizer object from the Keras Tokenizer class. It will be used to vectorize a text corpus, by turning each text into either a sequence of integers (each integer being the index of a token in a dictionary) or into a vector where the coefficient for each token could be binary, based on word count, based on tf-idf, etc.
#
#
#
# tokenizer.fit_on_texts(x_train): This updates the internal vocabulary based on a list of texts (x_train). It creates the word index, which is a dictionary mapping words (str) to their rank/index (int). The word index will have at most max_words - 1 words, with the 0 index reserved for padding and the last word index reserved for out-of-vocabulary (OOV) words.
#
#
#
# sequences = tokenizer.texts_to_sequences(x_train): This transforms each text in x_train into a sequence of integers. It replaces each word in the text with its corresponding integer from the word index created during fit_on_texts. The result is a list of sequences, where each sequence corresponds to a text in x_train.
#
#
#
#
# sequences_matrix = pad_sequences(sequences, maxlen=max_len): This pads each sequence in sequences to ensure that they all have the same length (max_len). Sequences longer than max_len are truncated from the beginning, and sequences shorter than max_len are padded with zeros at the beginning. This ensures that all sequences have consistent lengths, which is typically required for input to neural networks.

# %%
# Creating model architecture.
model = Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100,dropout=0.2,recurrent_dropout=0.2))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 300, 100)          5000000
#
#  spatial_dropout1d (Spatial  (None, 300, 100)          0
#  Dropout1D)
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 5080501 (19.38 MB)
# Trainable params: 5080501 (19.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# In this case, there are 100 units, which means that the LSTM layer has 100 internal memory cells. Increasing the number of units typically increases the model's capacity to learn complex patterns in the data, but it also increases the computational cost and the risk of overfitting, especially if the dataset is small.
#
# 100 specifies the number of units or neurons in the LSTM layer.

# %%
# starting model training
history1 = model.fit(sequences_matrix,y_train,batch_size=128,epochs = 3,
                   validation_split=0.2)
# Out:
# Epoch 1/3
# 204/204 [==============================] - 332s 2s/step - loss: 0.0849 - accuracy: 0.9682 - val_loss: 0.0874 - val_accuracy: 0.9655
# Epoch 2/3
# 204/204 [==============================] - 276s 1s/step - loss: 0.0436 - accuracy: 0.9848 - val_loss: 0.0913 - val_accuracy: 0.9664
# Epoch 3/3
# 204/204 [==============================] - 276s 1s/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.1227 - val_accuracy: 0.9572

# %%
test_sequences = tokenizer.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %% [markdown]
# ###MODEL EVALUATION

# %%
lstm_prediction = model.predict(test_sequences_matrix)
# Out:
# 255/255 [==============================] - 25s 95ms/step

# %%
res = []
for prediction in lstm_prediction:
    if prediction[0] < 0.5:
        res.append(0)
    else:
        res.append(1)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,res)
# Out:
# 0.9559887213436312

# %%
print(confusion_matrix(y_test,res))
# Out:
# [[3954   89]
#  [ 270 3844]]

# %%
import pickle
from keras.models import save_model

# %%
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# In the code snippet you provided, protocol=pickle.HIGHEST_PROTOCOL ensures that the tokenizer object is serialized using the most efficient protocol available in your Python version,

# %%
model.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
